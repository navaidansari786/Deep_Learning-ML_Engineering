# %%
# !wget https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip dataset.zip?dl=0
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "C:/Users/DR RISHI SINGH/facerecog/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "C:/Users/DR RISHI SINGH/facerecog/test", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 16.2667 - accuracy: 0.2156
# Epoch 00001: val_accuracy improved from -inf to 0.23438, saving model to best_model.h5
# 10/10 [==============================] - 22s 2s/step - loss: 16.2667 - accuracy: 0.2156 - val_loss: 16.4018 - val_accuracy: 0.2344
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 11.7148 - accuracy: 0.2969
# Epoch 00002: val_accuracy improved from 0.23438 to 0.27344, saving model to best_model.h5
# 10/10 [==============================] - 21s 2s/step - loss: 11.7148 - accuracy: 0.2969 - val_loss: 9.1338 - val_accuracy: 0.2734
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 7.8390 - accuracy: 0.3625
# Epoch 00003: val_accuracy improved from 0.27344 to 0.35156, saving model to best_model.h5
# 10/10 [==============================] - 22s 2s/step - loss: 7.8390 - accuracy: 0.3625 - val_loss: 7.1905 - val_accuracy: 0.3516
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 7.4264 - accuracy: 0.3750
# Epoch 00004: val_accuracy did not improve from 0.35156
# 10/10 [==============================] - 18s 2s/step - loss: 7.4264 - accuracy: 0.3750 - val_loss: 7.2210 - val_accuracy: 0.3359
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 7.7412 - accuracy: 0.3688
# Epoch 00005: val_accuracy improved from 0.35156 to 0.38281, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 7.7412 - accuracy: 0.3688 - val_loss: 6.2269 - val_accuracy: 0.3828
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0689 - accuracy: 0.4125
# Epoch 00006: val_accuracy improved from 0.38281 to 0.40234, saving model to best_model.h5
# 10/10 [==============================] - 20s 2s/step - loss: 6.0689 - accuracy: 0.4125 - val_loss: 6.7099 - val_accuracy: 0.4023
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 5.5334 - accuracy: 0.3875
# Epoch 00007: val_accuracy improved from 0.40234 to 0.44141, saving model to best_model.h5
# 10/10 [==============================] - 18s 2s/step - loss: 5.5334 - accuracy: 0.3875 - val_loss: 5.7887 - val_accuracy: 0.4414
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 4.5228 - accuracy: 0.4437
# Epoch 00008: val_accuracy did not improve from 0.44141
# 10/10 [==============================] - 16s 2s/step - loss: 4.5228 - accuracy: 0.4437 - val_loss: 5.5829 - val_accuracy: 0.3984
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 5.7412 - accuracy: 0.4219
# Epoch 00009: val_accuracy improved from 0.44141 to 0.44922, saving model to best_model.h5
# 10/10 [==============================] - 16s 2s/step - loss: 5.7412 - accuracy: 0.4219 - val_loss: 5.0799 - val_accuracy: 0.4492
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 4.9687 - accuracy: 0.5094
# Epoch 00010: val_accuracy did not improve from 0.44922
# 10/10 [==============================] - 16s 2s/step - loss: 4.9687 - accuracy: 0.5094 - val_loss: 7.4522 - val_accuracy: 0.4219
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 6.3774 - accuracy: 0.3719
# Epoch 00011: val_accuracy did not improve from 0.44922
# 10/10 [==============================] - 14s 1s/step - loss: 6.3774 - accuracy: 0.3719 - val_loss: 5.3410 - val_accuracy: 0.4297
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 5.8600 - accuracy: 0.4250
# Epoch 00012: val_accuracy did not improve from 0.44922
# 10/10 [==============================] - 14s 1s/step - loss: 5.8600 - accuracy: 0.4250 - val_loss: 6.1093 - val_accuracy: 0.3867
# Epoch 00012: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "anger-games.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of fear

# %%
import os
import cv2
import numpy as np
from keras.preprocessing import image
import warnings
warnings.filterwarnings("ignore")
from keras.preprocessing.image import load_img, img_to_array 
from keras.models import  load_model
import matplotlib.pyplot as plt
import numpy as np

# load model
model = load_model("best_model.h5")


face_haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture("The secrets to decoding facial expressions.mp4")
#cap = cv2.VideoCapture(0)

while True:
    ret, test_img = cap.read()  # captures frame and returns boolean value and captured image
    if not ret:
        continue
    gray_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)

    faces_detected = face_haar_cascade.detectMultiScale(gray_img, 1.32, 5)

    for (x, y, w, h) in faces_detected:
        cv2.rectangle(test_img, (x, y), (x + w, y + h), (255, 0, 0), thickness=7)
        roi_gray = gray_img[y:y + w, x:x + h]  # cropping region of interest i.e. face area from  image
        roi_gray = cv2.resize(roi_gray, (224, 224))
        img_pixels = image.img_to_array(roi_gray)
        img_pixels = np.expand_dims(img_pixels, axis=0)
        img_pixels /= 255

        predictions = model.predict(img_pixels)

        # find max indexed array
        max_index = np.argmax(predictions[0])

        emotions = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
        predicted_emotion = emotions[max_index]

        cv2.putText(test_img, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('Facial emotion analysis ', resized_img)

    if cv2.waitKey(10) == ord('q'):  # wait until 'q' key is pressed
        break

cap.release()
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>
